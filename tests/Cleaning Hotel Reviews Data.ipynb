# %%
import sys
sys.path.append('../src/')

from process_text import transforms
import pandas as pd

# %%
df = pd.read_csv('../datasets/reviews.csv')
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AWE2FvX5RxPSIh2RscTK  2018-01-18T18:43:12Z  2019-05-20T23:55:47Z
# 1  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 2  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 3  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 4  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
#
#                           address  \
# 0                 5620 Calle Real
# 1  5th And San Carlos PO Box 3574
# 2  5th And San Carlos PO Box 3574
# 3  5th And San Carlos PO Box 3574
# 4  5th And San Carlos PO Box 3574
#
#                                           categories  \
# 0  Hotels,Hotels and motels,Hotel and motel mgmt....
# 1                               Hotels,Lodging,Hotel
# 2                               Hotels,Lodging,Hotel
# 3                               Hotels,Lodging,Hotel
# 4                               Hotels,Lodging,Hotel
#
# ...

# %%
new_df = df[['id', 'reviews.text']]

# %%
reviews = new_df['reviews.text']

# %%
reviews.head(50)
# Out:
# 0     This hotel was nice and quiet. Did not know, t...
# 1     We stayed in the king suite with the separatio...
# 2     Parking was horrible, somebody ran into my ren...
# 3     Not cheap but excellent location. Price is som...
# 4     If you get the room that they advertised on th...
# 5     This is such a fun, lovely hotel. The attentio...
# 6     We recently stayed at this hotel on a trip to ...
# 7     I reserved a room a week in advance, knowing a...
# 8                                              MoreMore
# 9     Hello, I have traveled a lot and abroad and by...
# 10    This is a new Hampton Inn and is well decorate...
# 11    I stayed here for three nights while I explore...
# 12    Completely accommodating hotel! I booked a res...
# 13    The water is very hot and there's no cold wate...
# 14    Great staff and rooms. Housekeeping was always...
# 15    This Hotel, formerly a prestigious bank, may b...
# 16    Very accommodating staff. Competitive pricing ...
# ...

# %%
# object but can behave as a function due to __call__ method
trans = transforms.Compose([
    transforms.LowerCase(),
    transforms.RemoveSpecialCharacters(),
    transforms.HandleMispellings()
])

# %% [markdown]
# **Text-Wise Preprocessing**

# %%
trans(reviews[0])
# Out:
# 'this hotel was nice and quiet did not know there was train track near by but it was only few train passed during our stay best western changed hotel classification the plus category are not the same as before'

# %% [markdown]
# **`pd.Series`-Wise Preprocessing**
#
# - You may use the `pd.Series.apply` method to apply the `transforms` object as a function.

# %%
# object but can behave as a function due to __call__ method
trans = transforms.Compose([
    transforms.LowerCase(),
    transforms.RemoveSpecialCharacters(),
    # transforms.HandleMispellings()
])

# %%
reviews.apply(trans)
# Out:
# 0       this hotel was nice and quiet did not know the...
# 1       we stayed in the king suite with the separatio...
# 2       parking was horrible somebody ran into my rent...
# 3       not cheap but excellent location price is some...
# 4       if you get the room that they advertised on th...
#                               ...
# 9995    my friends and i took a trip to hampton for th...
# 9996    from check in to departure staff is friendly p...
# 9997    this hampton is located on a quiet street acro...
# 9998    awesome wings my favorite was garlic parmesan ...
# 9999    clean facility just off freeway  staff friendl...
# Name: reviews.text, Length: 10000, dtype: object

# %%
new_df.to_csv('../datasets/reviews2.csv')
